# %%
import pandas as pd 
import numpy as np

# %%
heros_info = pd.read_csv('./superhero-set/heroes_information.csv')
heros_power = pd.read_csv('./superhero-set/super_hero_powers.csv')

# %%
from sklearn import preprocessing

enc = preprocessing.OneHotEncoder()
enc.fit(heros_info['Eye color'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6839de501afe> in <module>()
#       2
#       3 enc = preprocessing.OneHotEncoder()
# ----> 4 enc.fit(heros_info['Eye color'])
#
# ~/.virtualenvs/tensorflow_sklearn_playground/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#    1954         self
#    1955         """
# -> 1956         self.fit_transform(X)
#    1957         return self
#    1958
#
# ~/.virtualenvs/tensorflow_sklearn_playground/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()

# %%
heros_info
# Out:
#      Unnamed: 0               name  Gender Eye color               Race  \
# 0             0             A-Bomb    Male    yellow              Human
# 1             1         Abe Sapien    Male      blue      Icthyo Sapien
# 2             2           Abin Sur    Male      blue            Ungaran
# 3             3        Abomination    Male     green  Human / Radiation
# 4             4            Abraxas    Male      blue      Cosmic Entity
# 5             5      Absorbing Man    Male      blue              Human
# 6             6        Adam Monroe    Male      blue                  -
# 7             7       Adam Strange    Male      blue              Human
# 8             8           Agent 13  Female      blue                  -
# 9             9          Agent Bob    Male     brown              Human
# 10           10         Agent Zero    Male         -                  -
# 11           11         Air-Walker    Male      blue                  -
# ...
